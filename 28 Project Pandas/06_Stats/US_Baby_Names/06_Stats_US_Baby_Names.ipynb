# %% [markdown]
# # US - Baby Names

# %% [markdown]
# ### Introduction:
#
# We are going to use a subset of [US Baby Names](https://www.kaggle.com/kaggle/us-baby-names) from Kaggle.
# In the file it will be names from 2004 until 2014
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US_Baby_Names/US_Baby_Names_right.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called baby_names.

# %%
baby_names = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US_Baby_Names/US_Baby_Names_right.csv")
baby_names
# Out:
#          Unnamed: 0       Id     Name  Year Gender State  Count
# 0             11349    11350     Emma  2004      F    AK     62
# 1             11350    11351  Madison  2004      F    AK     48
# 2             11351    11352   Hannah  2004      F    AK     46
# 3             11352    11353    Grace  2004      F    AK     44
# 4             11353    11354    Emily  2004      F    AK     41
# ...             ...      ...      ...   ...    ...   ...    ...
# 1016390     5647421  5647422     Seth  2014      M    WY      5
# 1016391     5647422  5647423  Spencer  2014      M    WY      5
# 1016392     5647423  5647424     Tyce  2014      M    WY      5
# 1016393     5647424  5647425   Victor  2014      M    WY      5
# 1016394     5647425  5647426   Waylon  2014      M    WY      5
#
# [1016395 rows x 7 columns]

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
baby_names.head(10)
# Out:
#    Unnamed: 0     Id      Name  Year Gender State  Count
# 0       11349  11350      Emma  2004      F    AK     62
# 1       11350  11351   Madison  2004      F    AK     48
# 2       11351  11352    Hannah  2004      F    AK     46
# 3       11352  11353     Grace  2004      F    AK     44
# 4       11353  11354     Emily  2004      F    AK     41
# 5       11354  11355   Abigail  2004      F    AK     37
# 6       11355  11356    Olivia  2004      F    AK     33
# 7       11356  11357  Isabella  2004      F    AK     30
# 8       11357  11358    Alyssa  2004      F    AK     29
# 9       11358  11359    Sophia  2004      F    AK     28

# %% [markdown]
# ### Step 5. Delete the column 'Unnamed: 0' and 'Id'

# %%
baby_names.drop(['Unnamed: 0','Id'],axis=1,inplace=True)
baby_names
# Out:
#             Name  Year Gender State  Count
# 0           Emma  2004      F    AK     62
# 1        Madison  2004      F    AK     48
# 2         Hannah  2004      F    AK     46
# 3          Grace  2004      F    AK     44
# 4          Emily  2004      F    AK     41
# ...          ...   ...    ...   ...    ...
# 1016390     Seth  2014      M    WY      5
# 1016391  Spencer  2014      M    WY      5
# 1016392     Tyce  2014      M    WY      5
# 1016393   Victor  2014      M    WY      5
# 1016394   Waylon  2014      M    WY      5
#
# [1016395 rows x 5 columns]

# %% [markdown]
# ### Step 6. Is there more male or female names in the dataset?

# %%
gender_count = baby_names['Gender'].value_counts()
pd.DataFrame(gender_count)
# Out:
#    Gender
# F  558846
# M  457549

# %% [markdown]
# ### Step 7. Group the dataset by name and assign to names

# %%
names = baby_names.groupby('Name')

# %%
for name,data in names:
  print(f"\nName {name}")
  print(data)
# Out:
# Streaming output truncated to the last 5000 lines.
#
# [154 rows x 5 columns]
#
# Name Zackariah
#              Name  Year Gender State  Count
# 115732  Zackariah  2006      M    CA      5
# 120424  Zackariah  2008      M    CA     10
# 127074  Zackariah  2010      M    CA      6
# 136128  Zackariah  2013      M    CA      5
# 214059  Zackariah  2006      M    FL      5
# 568204  Zackariah  2010      M    NC      6
# 719384  Zackariah  2007      M    OH      5
# 890491  Zackariah  2005      M    TX      5
# 892596  Zackariah  2006      M    TX      6
# 894871  Zackariah  2007      M    TX      7
# 897669  Zackariah  2008      M    TX      6
# 902833  Zackariah  2010      M    TX      6
# 907974  Zackariah  2012      M    TX      6
# 910934  Zackariah  2013      M    TX      5
#
# Name Zackary
#             Name  Year Gender State  Count
# 3009     Zackary  2006      M    AK      6
# 3741     Zackary  2009      M    AK      5
# 4474     Zackary  2012      M    AK      5
# ...

# %% [markdown]
# ### Step 8. How many different names exist in the dataset?

# %%
number_unique_names = baby_names['Name'].nunique()
print(f"Number different names exist in the dataset is : {number_unique_names}")
# Out:
# Number different names exist in the dataset is : 17632

# %% [markdown]
# ### Step 9. What is the name with most occurrences?

# %%
most_occ_name = baby_names['Name'].value_counts().idxmax()
most_occ_name_number = baby_names['Name'].value_counts().max()
print(f"Name with most occurrences '{most_occ_name}' , with number '{most_occ_name_number}'")
# Out:
# Name with most occurrences 'Riley' , with number '1112'

# %% [markdown]
# ### Step 10. How many different names have the least occurrences?

# %%
least_occ_name = baby_names['Name'].value_counts().idxmin()
least_occ_name_number = baby_names['Name'].value_counts().min()
print(f"Name with least occurrences '{least_occ_name}' , with number '{least_occ_name_number}'")
# Out:
# Name with least occurrences 'Grettell' , with number '1'

# %% [markdown]
# ### Step 11. What is the median name occurrence?

# %%
median_name = baby_names['Name'].value_counts().median()
print(f"Median name occurrence : {median_name}")
# Out:
# Median name occurrence : 8.0

# %% [markdown]
# ### Step 12. What is the standard deviation of names?

# %%
median_name = baby_names['Name'].value_counts().std()
print(f"Standard deviation of names : {median_name}")
# Out:
# Standard deviation of names : 122.0299635081389

# %% [markdown]
# ### Step 13. Get a summary with the mean, min, max, std and quartiles.

# %%
baby_names.describe()
# Out:
#                Year         Count
# count  1.016395e+06  1.016395e+06
# mean   2.009053e+03  3.485012e+01
# std    3.138293e+00  9.739735e+01
# min    2.004000e+03  5.000000e+00
# 25%    2.006000e+03  7.000000e+00
# 50%    2.009000e+03  1.100000e+01
# 75%    2.012000e+03  2.600000e+01
# max    2.014000e+03  4.167000e+03
