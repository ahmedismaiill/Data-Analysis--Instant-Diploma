# %% [markdown]
# # Iris

# %% [markdown]
# ### Introduction:
#
# This exercise may seem a little bit strange, but keep doing it.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data).

# %% [markdown]
# ### Step 3. Assign it to a variable called iris

# %%
iris = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data",names=['sepal_length (in cm)','sepal_width (in cm)','petal_length (in cm)','petal_width (in cm)','class'])
iris
# Out:
#      sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                     5.1                  3.5                   1.4
# 1                     4.9                  3.0                   1.4
# 2                     4.7                  3.2                   1.3
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# ..                    ...                  ...                   ...
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      petal_width (in cm)           class
# 0                    0.2     Iris-setosa
# 1                    0.2     Iris-setosa
# ...

# %% [markdown]
# ### Step 4. Create columns for the dataset

# %%
# 1. sepal_length (in cm)
# 2. sepal_width (in cm)
# 3. petal_length (in cm)
# 4. petal_width (in cm)
# 5. class

# %% [markdown]
# ### Step 5.  Is there any missing value in the dataframe?

# %%
missing_values = iris.isnull().sum()
print("Missing values in the DataFrame:")
print(missing_values)
# Out:
# Missing values in the DataFrame:
# sepal_length (in cm)    0
# sepal_width (in cm)     0
# petal_length (in cm)    0
# petal_width (in cm)     0
# class                   0
# dtype: int64

# %% [markdown]
# ### Step 6.  Lets set the values of the rows 10 to 29 of the column 'petal_length' to NaN

# %%
iris.loc[10:29, 'petal_length (in cm)'] = np.nan
iris.loc[10:29, 'petal_length (in cm)']
# Out:
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# 25   NaN
# 26   NaN
# 27   NaN
# 28   NaN
# 29   NaN
# Name: petal_length (in cm), dtype: float64

# %% [markdown]
# ### Step 7. Good, now lets substitute the NaN values to 1.0

# %%
iris['petal_length (in cm)'].fillna(1.0, inplace=True)

# %% [markdown]
# ### Step 8. Now let's delete the column class

# %%
iris.drop('class',axis=1,inplace=True)
iris.head()
# Out:
#    sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
#
#    petal_width (in cm)
# 0                  0.2
# 1                  0.2
# 2                  0.2
# 3                  0.2
# 4                  0.2

# %% [markdown]
# ### Step 9.  Set the first 3 rows as NaN

# %%
iris.loc[0:2,:] = np.nan
iris
# Out:
#      sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                     NaN                  NaN                   NaN
# 1                     NaN                  NaN                   NaN
# 2                     NaN                  NaN                   NaN
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# ..                    ...                  ...                   ...
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      petal_width (in cm)
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    0.2
# ...

# %% [markdown]
# ### Step 10.  Delete the rows that have NaN

# %%
iris.dropna(how='all',inplace=True)
iris.head()
# Out:
#    sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
#
#    petal_width (in cm)
# 3                  0.2
# 4                  0.2
# 5                  0.4
# 6                  0.3
# 7                  0.2

# %% [markdown]
# ### Step 11. Reset the index so it begins with 0 again

# %%
iris.reset_index(drop=True, inplace=True)
iris.head()
# Out:
#    sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                   4.6                  3.1                   1.5
# 1                   5.0                  3.6                   1.4
# 2                   5.4                  3.9                   1.7
# 3                   4.6                  3.4                   1.4
# 4                   5.0                  3.4                   1.5
#
#    petal_width (in cm)
# 0                  0.2
# 1                  0.2
# 2                  0.4
# 3                  0.3
# 4                  0.2
